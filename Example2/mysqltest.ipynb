# %%
import pandas as pd

# %%
df = pd.read_csv("customers.csv", na_values=["NULL"], on_bad_lines='skip')

# df = pd.read_csv("customers.csv")

# %%
df.head(10)
# Out:
#   customerID                         companyName         contactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                  Berglunds snabbköp  Christina Berglund
# 5      BLAUS             Blauer See Delikatessen          Hanna Moos
# 6      BOTTM               Bottom-Dollar Markets   Elizabeth Lincoln
# 7      BSBEV                       B's Beverages   Victoria Ashworth
# 8      CACTU          Cactus Comidas para llevar    Patricio Simpson
# 9      CENTC          Centro comercial Moctezuma     Francisco Chang
#
#            contactTitle                        address          city region  \
# 0  Sales Representative                  Obere Str. 57        Berlin    NaN
# ...

# %%
# column "region" will be dropped 
# because it has so many NaN (missing values)
df = df.drop(columns=['region'])

# %%
df.head()
# Out:
#   customerID                         companyName         contactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                  Berglunds snabbköp  Christina Berglund
#
#            contactTitle                        address         city  \
# 0  Sales Representative                  Obere Str. 57       Berlin
# 1                 Owner  Avda. de la Constitución 2222  México D.F.
# 2                 Owner                Mataderos  2312  México D.F.
# 3  Sales Representative                120 Hanover Sq.       London
# 4   Order Administrator                Berguvsvägen  8        Luleå
#
#   postalCode  country           phone             fax
# 0      12209  Germany     030-0074321     030-0076545
# ...

# %%
df = pd.read_csv("orders.csv", na_values=["NULL"], on_bad_lines='skip')

# %%
df.head()
# Out:
#    orderID customerID  employeeID                orderDate  \
# 0    10248      VINET           5  1996-07-04 00:00:00.000
# 1    10249      TOMSP           6  1996-07-05 00:00:00.000
# 2    10254      CHOPS           5  1996-07-11 00:00:00.000
# 3    10255      RICSU           9  1996-07-12 00:00:00.000
# 4    10257      HILAA           4  1996-07-16 00:00:00.000
#
#               requiredDate              shippedDate  shipVia  freight  \
# 0  1996-08-01 00:00:00.000  1996-07-16 00:00:00.000        3    32.38
# 1  1996-08-16 00:00:00.000  1996-07-10 00:00:00.000        1    11.61
# 2  1996-08-08 00:00:00.000  1996-07-23 00:00:00.000        2    22.98
# 3  1996-08-09 00:00:00.000  1996-07-15 00:00:00.000        3   148.33
# 4  1996-08-13 00:00:00.000  1996-07-22 00:00:00.000        3    81.91
#
#                     shipName                                 shipAddress  \
# 0  Vins et alcools Chevalier                          59 rue de l'Abbaye
# ...

# %%
# Drop columns multiple column 
#df = df.drop(['B', 'C'], axis=1)
# dropping multiple columns

# %%
# saving the clean csv
# df.to_csv("car_purchasingNew2.csv", index=False)
