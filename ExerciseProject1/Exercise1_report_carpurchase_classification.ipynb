# %% [markdown]
#  <h1>Car purchase data, dataset optimization analysis</h1>
#
#  <h5>In this case, the target variable is "car_purchase_amount" in the classification.</h5>

# %% [markdown]
# <h3> Variables that can be dropped are listed below or be processed further</h3>
# <ul>
#     <li>There is missing values in the column Benefits</li>
#     <li>No duplicates in the dataset</li>
#     <li>There are variables (columns) not as important in tha dataset</li>
#     <li>Such as 'JobTitle', 'customer_email', 'country',</li>
#     <li>And 'gender', 'customer_name'</li>
#     <li>As these variable has less significant influence in the data</li>
# </ul>

# %% [markdown]
# <h3>Correlations</h3>
# <ul>
#     <li>Net worth is highly correlated to car_purchase_amount</li>
#     <li>Age too indicates that there's relatively correlation </li>
#     <li>Other variables are relatively less important</li>
# </ul>

# %% [markdown]
# <h3>Data imbalance</h3>
# <ul>
#     <li>The dataset has data imbalance</li>
#     <li>There is much to be done on the dataset</li>
#     <li>Data imbalance in OtherPay, TotalPay</li>
#     <li>And TotalPayBenefits</li>
# </ul>

# %% [markdown]
# <h3>Distribution</h3>
# <ul>
#     <li>Over all, I would say the distribution in this dataset is not normal</li>
#
#
#
#
#
#
#
# </ul>

# %% [markdown]
# <ul><li>Age is quite normal in this dataset</li></ul>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <ul><li>BasePay variable is not totally normal as shown below</li></ul>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <ul><li>These variables are not normal as shown below</li></ul>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <ul><li>These variables are quite normal below</li></ul>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>VIF</h3>
#
# ![image.png](attachment:image.png)
# <ul>
# <li>Variables with infinite VIF values maybe decided to be dropped </li>
# <li>This is often because the features are quite collinear with other features</li>
# <li>The pay-related features are likely highly correlated</li>
# <li>TotalPay could be related to OtherPay, BasePay, OvertimePay</li>
# <li>And TotalPayBenefits include the TotalPay</li>
#
# </ul>

# %% [markdown]
# <h3>SHAP</h3>
# <ul>
#     <li>The SHAP tool shows the most important variables in the dataset</li>
#
# </ul>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>Optimization</h3>
# <ul>
#     <li>Quite some things to do like below</li>
#     <li>There is need to drop some variable columns</li>
#     <li>Make use of encoding='ISO-8859-1'</li>
#     <li>So that the dataset be readable in pandas </li>
#     <li>Replace missing values though I drop the column 'Benefits' but in practical I will replace the values</li>
#     <li>In this case the column 'Benefits' will be dropped</li>
#     <li>Remove some outliers</li>
#     <li>Drop redundants variables</li>
#     <li>Such as BasePay, OvertimePay and OtherPay</li>
#
# </ul>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>Overlapping</h3>
# <ul>
# <li>The "TotalPay" variable is the overlap here I think </li>
# <li>As it potentially has the total sum of other pay variables</li>
# <li>Such as OtherPay, BasePay and OvertimePay which are the redundant variables</li>
# <li>I think TotalPayBenefits could be excluded as redundancy from the TotalPay </li>
# </ul>
#
# ![image-6.png](attachment:image-6.png)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# <h3>Outliers and Noise using Autoviz</h3>
# <ul>
# <li>The are three independent variables with outliers</li>
# <li>OtherPay has the highest outliers which is greater than the upper bound</li>
# <li>TotalPay quite have outliers too</li>
# <li>And TotalPayBenefits has same outliers as TotalPay</li>
# <li>For the efficiency of my model I thinl IQR, z score</li>
# <li>Would be nice tools to remove the outliers</li>
# <li>There is noise in BasePay when at 1.500e+5 as shown with pair-wise scatter plot with autoviz</li>
# </ul>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
